# %% [markdown]
# # Fine-Tuning on Pre-Training Data: A Model Comparison
#
# In this notebook, we fine-tune a large language model (LLM) on the Bible (using both standard and parameter-efficient fine-tuning) and evaluate any potential performance increase on the BibleQA dataset.
#
# To start, we install and import our necessary dependencies.

# %%
# !pip install transformers datasets peft pandas tqdm seaborn torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.21.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (0.12.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.5)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from peft) (0.32.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.20)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
import csv
import torch
import pandas as pd
from tqdm import tqdm
import seaborn as sns
from datasets import load_dataset
from peft import get_peft_model, LoraConfig
from transformers import (
    AutoTokenizer, AutoModelForCausalLM,
    Trainer, TrainingArguments, TrainerCallback,
    DataCollatorForLanguageModeling
)
N_FINE_TUNING_EPOCHS = 1
FINE_TUNING_BATCH_SIZE = 8

# %% [markdown]
# Next, we load in the biblical text as a Hugging Face dataset for later fine-tuning.

# %%
bible_text_dataset = load_dataset('text', data_files={'train': 'bible.txt'})
bible_text_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 31104
#     })
# })

# %% [markdown]
# Before proceeding, we print a sample from the Bible dataset as a sanity check.

# %%
bible_text_dataset['train'][3000]['text']
# Out:
# 'Leviticus 11:1\tAnd Jehovah spake unto Moses and to Aaron, saying unto them,'

# %% [markdown]
# We now prepare our BibleQA dataset as question-answer pairs and display a sample.

# %%
bible_qa_pairs = {
    'questions': [],
    'answers': []
}
with open('bible_qa_pairs.csv') as bible_qa_pairs_csv_file:
    bible_qa_csv_file_reader = csv.reader(bible_qa_pairs_csv_file, delimiter='\t')
    header = next(bible_qa_csv_file_reader)
    for row in bible_qa_csv_file_reader:
        if row:
            bible_qa_pairs['questions'].append(
                ''.join(row[0].split('. ')[1:]))
            bible_qa_pairs['answers'].append(
                ''.join(''.join(row[1].split('. ')[1:]).split(' (')[:1]))
bible_qa_pairs_df = pd.DataFrame(bible_qa_pairs)
bible_qa_pairs_df.head()
# Out:
#                                            questions  \
# 0                What was the name of Jesus' mother?
# 1  What was the name of the garden where Adam and...
# 2       With what food did Jesus feed the multitude?
# 3      What method did the Romans use to kill Jesus?
# 4  From which part of Adam's body did God create ...
#
#                       answers
# 0                        Mary
# 1                        Eden
# 2  Five loaves and two fishes
# 3                 Crucifixion
# 4                         Rib

# %% [markdown]
# We should now load in both our models and our tokenizer. In the case of the former, we load in three instances of the model, one for each of our evaluations.

# %%
model_name = 'openai-community/gpt2-large'
pretrained_model = AutoModelForCausalLM.from_pretrained(model_name)
fine_tuned_model = AutoModelForCausalLM.from_pretrained(model_name)
peft_model = AutoModelForCausalLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# Now that we have our tokenizer, we can tokenize our biblical text for fine-tuning.

# %%
def tokenize_bible_text(examples):
    return tokenizer(
        examples['text'], truncation=True,
        padding='max_length', max_length=512
    )
tokenized_bible_text = bible_text_dataset.map(
    tokenize_bible_text, batched=True
)

# %% [markdown]
# Before we dig into fine-tuning, we create a callback that will collect the loss over time from fine-tuning.

# %%
class LossCallback(TrainerCallback):
    def __init__(self):
        self.losses = []

    def on_log(self, args, state, control, logs=None, **kwargs):
        if 'loss' in logs:
            self.losses.append(logs['loss'])

fine_tuned_loss_callback = LossCallback()
peft_loss_callback = LossCallback()

# %% [markdown]
# Fine-tuning can now take place. We first fine-tune in a straightforward fashion, simply performing more training but with our specific data. Note that the epoch count was set to 4 and the batch size to 8 as global variables above. (For fair comparison, these same hyperparameters will also be set for PEFT.)

# %%
fined_tuned_data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)
fine_tuned_training_args = TrainingArguments(
    output_dir='./fine_tuning_results',
    overwrite_output_dir=True,
    num_train_epochs=N_FINE_TUNING_EPOCHS,
    per_device_train_batch_size=FINE_TUNING_BATCH_SIZE,
    save_strategy='no'
)
fine_tuned_trainer = Trainer(
    model=fine_tuned_model,
    args=fine_tuned_training_args,
    train_dataset=tokenized_bible_text['train'],
    data_collator=fined_tuned_data_collator,
    callbacks=[fine_tuned_loss_callback]
)
fine_tuned_trainer.train()
# Out:
#     <div>
#
#       <progress value='3888' max='3888' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3888/3888 1:26:17, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>2.670500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>2.482700</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>2.421300</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.361100</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2.297100</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.258800</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>2.239400</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=3888, training_loss=2.369650318789384, metrics={'train_runtime': 5179.531, 'train_samples_per_second': 6.005, 'train_steps_per_second': 0.751, 'total_flos': 6.76877568049152e+16, 'train_loss': 2.369650318789384, 'epoch': 1.0})

# %% [markdown]
# We also visualize the loss curve produced from fine-tuning.

# %%
fine_tuned_losses = fine_tuned_loss_callback.losses
fine_tuned_loss_lineplot = sns.lineplot(
    x=[(step + 1) * 500 for step in range(len(fine_tuned_losses))],
    y=fine_tuned_losses
)
fine_tuned_loss_lineplot.set(
    title='Fine-Tuning Model Loss',
    xlabel='Training Steps', ylabel='Loss'
)
fine_tuned_loss_lineplot
# Out:
# <Axes: title={'center': 'Fine-Tuning Model Loss'}, xlabel='Training Steps', ylabel='Loss'>

# %% [markdown]
# Before performing parameter-efficient fine-tuning (PEFT), we need to determine which parts of the model to apply it to. Our `gpt2-large` model features the following structure.

# %%
peft_model
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 1280)
#     (wpe): Embedding(1024, 1280)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-35): 36 x GPT2Block(
#         (ln_1): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2SdpaAttention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1280, out_features=50257, bias=False)
# )

# %% [markdown]
# The bulk of the model is a series of 36 `GPT2Block` modules. The parameter-containing modules within a given `GPT2Block` are `c_attn` (convolutional attention), `c_fc` (fully connected convolutional), `c_proj` (convolutional projection). Note that the latter is a part of both the attention portion and the multi-layer perceptron (MLP) portion. Before selecting which layers we'd like to apply PEFT to, let's see what the parameter counts of these layers are.

# %%
for name, module in peft_model.named_modules():
    if 'c_' in name and 'transformer.h.0' in name: # We only need to see counts
                                                   # for one GPT2Block
        layer_params = sum(p.numel() for p in module.parameters())
        print(f"Layer: {name}, Parameters: {layer_params}")
# Out:
# Layer: transformer.h.0.attn.c_attn, Parameters: 4919040
# Layer: transformer.h.0.attn.c_proj, Parameters: 1639680
# Layer: transformer.h.0.mlp.c_fc, Parameters: 6558720
# Layer: transformer.h.0.mlp.c_proj, Parameters: 6554880

# %% [markdown]
# All of these modules contain a very high number of parameters. We will thus apply PEFT to all of them, namely in the form of low-rank adaptation (LoRA).

# %%
lora_config = LoraConfig(
    target_modules=['c_attn', 'c_proj', 'c_fc']
)
peft_model = get_peft_model(peft_model, lora_config)

peft_data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)
peft_training_args = TrainingArguments(
    output_dir='./peft_results',
    overwrite_output_dir=True,
    num_train_epochs=N_FINE_TUNING_EPOCHS,
    per_device_train_batch_size=FINE_TUNING_BATCH_SIZE,
    save_strategy='no'
)
peft_trainer = Trainer(
    model=peft_model,
    args=peft_training_args,
    train_dataset=tokenized_bible_text['train'],
    data_collator=peft_data_collator,
    callbacks=[peft_loss_callback]
)
peft_trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/tuners/lora/layer.py:1091: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(
#     <div>
#
#       <progress value='3888' max='3888' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3888/3888 1:06:45, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>2.908200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>2.545000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>2.512800</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.489500</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2.471300</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.459900</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>2.477200</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=3888, training_loss=2.5404022907523953, metrics={'train_runtime': 4006.5879, 'train_samples_per_second': 7.763, 'train_steps_per_second': 0.97, 'total_flos': 6.825134241349632e+16, 'train_loss': 2.5404022907523953, 'epoch': 1.0})

# %% [markdown]
# As above, we visualize the loss curve.

# %%
peft_losses = peft_loss_callback.losses
peft_loss_lineplot = sns.lineplot(
    x=[(step + 1) * 500 for step in range(len(peft_losses))],
    y=peft_losses
)
peft_loss_lineplot.set(
    title='PEFT Model Loss',
    xlabel='Training Steps', ylabel='Loss'
)
peft_loss_lineplot
# Out:
# <Axes: title={'center': 'PEFT Model Loss'}, xlabel='Training Steps', ylabel='Loss'>

# %% [markdown]
# Finally, we can evaluate our models on the question-answer pairs. Note that we embed our questions into a few-shot learning prompt to encourage the text-continuation model to output answers to the question (we also explicitly inform the model of the biblical nature of the questions).

# %%
def generate_answer(model: AutoModelForCausalLM, question: str) -> str:
    if not question.strip():
        return ''

    prompt =\
    f'The following are questions and answers about the Bible.\n\n\
Q: Who was the first man?\n\
A: Adam\n\n\
Q: What was special about Samson?\n\
A: He was very strong\n\n\
Q: Where was Jesus born?\n\
A: Bethlehem\n\n\
Q: {question}\n\
A: '
    input_tokens = tokenizer.encode(
        question,
        return_tensors='pt'
    ).to(model.device)
    attention_mask = input_tokens.ne(
        tokenizer.pad_token_id
    ).to(model.device)
    model_output = model.generate(
        input_tokens,
        max_new_tokens=15,
        num_return_sequences=1,
        pad_token_id=tokenizer.eos_token_id,
        attention_mask=attention_mask
    )
    answer = tokenizer.decode(
        model_output[0],
        skip_special_tokens=True
    )
    answer = answer.replace(prompt, '')
    return answer

pretrained_model_answers = []
fine_tuned_model_answers = []
peft_model_answers = []
for question in tqdm(bible_qa_pairs_df['questions']):
    pretrained_model_answers.append(
        generate_answer(pretrained_model, question))
    fine_tuned_model_answers.append(
        generate_answer(fine_tuned_model, question))
    peft_model_answers.append(
        generate_answer(peft_model, question))

bible_qa_pairs_df['pretrained_model_answers'] = pretrained_model_answers
bible_qa_pairs_df['fine_tuned_model_answers'] = fine_tuned_model_answers
bible_qa_pairs_df['peft_model_answers'] = peft_model_answers
bible_qa_pairs_df.head()
# Out:
# 100%|██████████| 886/886 [36:13<00:00,  2.45s/it]
#                                            questions  \
# 0                What was the name of Jesus' mother?
# 1  What was the name of the garden where Adam and...
# 2       With what food did Jesus feed the multitude?
# 3      What method did the Romans use to kill Jesus?
# 4  From which part of Adam's body did God create ...
#
#                       answers  \
# 0                        Mary
# 1                        Eden
# 2  Five loaves and two fishes
# 3                 Crucifixion
# 4                         Rib
#
#                             pretrained_model_answers  \
# 0  What was the name of Jesus' mother?\n\nThe nam...
# 1  What was the name of the garden where Adam and...
# 2  With what food did Jesus feed the multitude?\n...
# 3  What method did the Romans use to kill Jesus?\...
# 4  From which part of Adam's body did God create ...
#
#                             fine_tuned_model_answers  \
# 0  What was the name of Jesus' mother? She was th...
# 1  What was the name of the garden where Adam and...
# 2  With what food did Jesus feed the multitude? A...
# 3  What method did the Romans use to kill Jesus? ...
# 4  From which part of Adam's body did God create ...
#
#                                   peft_model_answers
# 0  What was the name of Jesus' mother?\n\nA: She ...
# 1  What was the name of the garden where Adam and...
# 2  With what food did Jesus feed the multitude? A...
# 3  What method did the Romans use to kill Jesus?\...
# 4  From which part of Adam's body did God create ...

# %% [markdown]
# Finally, we can evaluate these responses against our ground-truth answers. For the sake of simplicity, an answer produced by the model was considered correct if the ground-truth answer was at least contained _somewhere_ within the response. When at least one model response is counted as correct for a given question, the question, the ground-truth answer, and each model's response is printed for observation.

# %%
pretrained_correct = 0
fine_tuned_correct = 0
peft_correct = 0
bible_qa_rows = bible_qa_pairs_df.to_dict(orient='records')
for row_index, row in enumerate(bible_qa_rows):
    one_correct = False
    if row['answers'] in row['pretrained_model_answers']:
        pretrained_correct += 1
        one_correct = True
    if row['answers'] in row['fine_tuned_model_answers']:
        fine_tuned_correct += 1
        one_correct = True
    if row['answers'] in row['peft_model_answers']:
        peft_correct += 1
        one_correct = True
    if one_correct:
        print( '------------------')
        print(f'QUESTION {row_index + 1}')
        print(f'Question: {row["questions"]}')
        print(f'Answer: {row["answers"]}')
        print(f'Pre-trained Model Answer: {row["pretrained_model_answers"]}')
        print(f'Fine-tuned Model Answer: {row["fine_tuned_model_answers"]}')
        print(f'PEFT Model Answer: {row["peft_model_answers"]}')
        print( '------------------\n\n')
# Out:
# ------------------
# QUESTION 1
# Question: What was the name of Jesus' mother?
# Answer: Mary
# Pre-trained Model Answer: What was the name of Jesus' mother?
#
# The name of Jesus' mother was Mary.
#
# Was Jesus
# Fine-tuned Model Answer: What was the name of Jesus' mother? She was the daughter of Joseph, the son of Joseph, the son of
# PEFT Model Answer: What was the name of Jesus' mother?
#
# A: She was called Mary.
#
# B: And what
# ------------------
#
#
# ------------------
# QUESTION 2
# Question: What was the name of the garden where Adam and Eve lived?
# Answer: Eden
# Pre-trained Model Answer: What was the name of the garden where Adam and Eve lived?
#
# The Garden of Eden.
#
# What was the name of the
# Fine-tuned Model Answer: What was the name of the garden where Adam and Eve lived? And the name of the tree was called the garden of Eden. And the
# PEFT Model Answer: What was the name of the garden where Adam and Eve lived? Was it the garden of the knowledge of good and evil? Was it the
# ------------------
#
#
# ------------------
# QUESTION 31
# Question: Who was David's father?
# Answer: Jesse
# Pre-trained Model Answer: Who was David's father?
#
# David's father was a man named David. He was a farmer
# Fine-tuned Model Answer: Who was David's father? And who was the son of Jesse? And who was the son of David
# PEFT Model Answer: Who was David's father?
#
# And what was his name?
#
# And what was his father
# ------------------
#
#
# ------------------
# QUESTION 35
# Question: Who wrote the letter to Philemon?
# Answer: Paul
# Pre-trained Model Answer: Who wrote the letter to Philemon?
#
# The letter was written by a man named John, who was a
# Fine-tuned Model Answer: Who wrote the letter to Philemon? And who wrote the letter to the prophets? And who wrote the letter to
# PEFT Model Answer: Who wrote the letter to Philemon?
#
# The letter to Philemon was written by the apostle Paul,
# ------------------
#
#
# ------------------
# QUESTION 37
# Question: What was the name of Moses' brother?
# Answer: Aaron
# Pre-trained Model Answer: What was the name of Moses' brother?
#
# Moses was the brother of Aaron, the brother of Levi,
# Fine-tuned Model Answer: What was the name of Moses' brother? And they said, The son of Jesse. And they said, The son
# PEFT Model Answer: What was the name of Moses' brother? It was the son of the man that was called Moses. And Moses said
# ------------------
#
#
# ------------------
# QUESTION 43
# Question: From which country did Moses help the Israelites escape from their lives of slavery?
# Answer: Egypt
# Pre-trained Model Answer: From which country did Moses help the Israelites escape from their lives of slavery?
#
# Moses was born in Egypt, and his father was a Pharaoh
# Fine-tuned Model Answer: From which country did Moses help the Israelites escape from their lives of slavery? And he said, I will not go with them, neither will I go
# PEFT Model Answer: From which country did Moses help the Israelites escape from their lives of slavery? And how did he do it? And how did he do it? And
# ------------------
#
#
# ------------------
# QUESTION 48
# Question: What was the name of the tower that the people were building when God confused their language?
# Answer: Tower of Babel
# Pre-trained Model Answer: What was the name of the tower that the people were building when God confused their language?
#
# The tower was called "The Tower of Babel" because it was
# Fine-tuned Model Answer: What was the name of the tower that the people were building when God confused their language? And the name of the city that the people dwelt in when they were
# PEFT Model Answer: What was the name of the tower that the people were building when God confused their language?
#
# And the people said, The tower of Babel.
#
# And
# ------------------
#
#
# ------------------
# QUESTION 50
# Question: Which sea did the Israelites cross through to escape the Egyptians?
# Answer: Red Sea
# Pre-trained Model Answer: Which sea did the Israelites cross through to escape the Egyptians?
#
# The Israelites crossed the Red Sea to escape the Egyptians.
#
# Fine-tuned Model Answer: Which sea did the Israelites cross through to escape the Egyptians? And the Egyptians said, The sea of the Jordan. And the Israelites
# PEFT Model Answer: Which sea did the Israelites cross through to escape the Egyptians? The sea of the Red Sea. And the sea of the Jordan, the
# ------------------
#
#
# ------------------
# QUESTION 63
# Question: Who was Solomon's father?
# Answer: David
# Pre-trained Model Answer: Who was Solomon's father?
#
# Solomon's father was Solomon, the son of David.
#
# Fine-tuned Model Answer: Who was Solomon's father? And he was the son of David, the son of Jesse, the son
# PEFT Model Answer: Who was Solomon's father? Eliezer the son of Reuben. And Solomon was his father.
# ------------------
#
#
# ------------------
# QUESTION 100
# Question: Abraham's wife Sarah bore a special sonWhat was his name?
# Answer: Isaac
# Pre-trained Model Answer: Abraham's wife Sarah bore a special sonWhat was his name? Abraham's son Isaac.
#
# Abraham's wife Sarah bore a special
# Fine-tuned Model Answer: Abraham's wife Sarah bore a special sonWhat was his name? And Abraham said, Isaac. And Isaac was the father of all the children
# PEFT Model Answer: Abraham's wife Sarah bore a special sonWhat was his name? Is it not Abraham? And he called his name Isaac. And he was
# ------------------
#
#
# ------------------
# QUESTION 103
# Question: To which city will all nations one day go to worship God?
# Answer: Jerusalem
# Pre-trained Model Answer: To which city will all nations one day go to worship God?
#
# And what is the meaning of the word "God"?
#
#
# Fine-tuned Model Answer: To which city will all nations one day go to worship God? And where will all nations be gathered together? And where will all nations be
# PEFT Model Answer: To which city will all nations one day go to worship God? And why should they not come to Jerusalem, and to the house of the
# ------------------
#
#
# ------------------
# QUESTION 132
# Question: In which town was Jesus born?
# Answer: Bethlehem
# Pre-trained Model Answer: In which town was Jesus born?
#
# The answer is in the Gospels.
#
# The first Gospel
# Fine-tuned Model Answer: In which town was Jesus born? Bethlehem of Judæa. And where was he? Bethlehem of the tribe
# PEFT Model Answer: In which town was Jesus born? In Bethlehem of Judea, in the days of Herod the king. And
# ------------------
#
#
# ------------------
# QUESTION 135
# Question: Which garden did Jesus go to to pray in before his arrest?
# Answer: Gethsemane
# Pre-trained Model Answer: Which garden did Jesus go to to pray in before his arrest?
#
# The Garden of Gethsemane.
#
# The Garden
# Fine-tuned Model Answer: Which garden did Jesus go to to pray in before his arrest? And where did he pray in the temple? And where did he eat bread
# PEFT Model Answer: Which garden did Jesus go to to pray in before his arrest? The garden of the fig-tree, the tree of the knowledge of good
# ------------------
#
#
# ------------------
# QUESTION 142
# Question: To which country did Mary and Joseph escape when Herod killed all the babies in Bethlehem?
# Answer: Egypt
# Pre-trained Model Answer: To which country did Mary and Joseph escape when Herod killed all the babies in Bethlehem?
#
# The answer is that they escaped to Egypt.
#
# The Bible
# Fine-tuned Model Answer: To which country did Mary and Joseph escape when Herod killed all the babies in Bethlehem? And where is the place of the tomb of the Lord? And where is
# PEFT Model Answer: To which country did Mary and Joseph escape when Herod killed all the babies in Bethlehem? And where is the place where they were taken? And where is the place
# ------------------
#
#
# ------------------
# QUESTION 143
# Question: What is the name of the angel who appeared to Mary?
# Answer: Gabriel
# Pre-trained Model Answer: What is the name of the angel who appeared to Mary?
#
# Answer: The angel who appeared to Mary was the angel Gabriel.
# Fine-tuned Model Answer: What is the name of the angel who appeared to Mary? And he said, The Lord is my shepherd; he shall guide me in
# PEFT Model Answer: What is the name of the angel who appeared to Mary?
#
# A prophet.
#
# And what was the name of the angel
# ------------------
#
#
# ------------------
# QUESTION 144
# Question: Which land did the Lord promise to Abram?
# Answer: Canaan
# Pre-trained Model Answer: Which land did the Lord promise to Abram?
#
# Abram was a descendant of Ham, and his father was a
# Fine-tuned Model Answer: Which land did the Lord promise to Abram? And he said, I will not go up to the land of Canaan,
# PEFT Model Answer: Which land did the Lord promise to Abram? And he said, The land of Canaan. And he said, I will
# ------------------
#
#
# ------------------
# QUESTION 155
# Question: On what mountain did Moses receive the law from God?
# Answer: Mount Sinai
# Pre-trained Model Answer: On what mountain did Moses receive the law from God?
#
# Moses received the law from God on Mount Sinai.
#
#
# Fine-tuned Model Answer: On what mountain did Moses receive the law from God? And he said, The mount of God, which is in the midst of
# PEFT Model Answer: On what mountain did Moses receive the law from God? From the mountain of God, from the mountain of God, from the mountain
# ------------------
#
#
# ------------------
# QUESTION 156
# Question: Which of his wives did Jacob love the most?
# Answer: Rachel
# Pre-trained Model Answer: Which of his wives did Jacob love the most?
#
# Jacob's answer:
#
# "I love Rachel more than all
# Fine-tuned Model Answer: Which of his wives did Jacob love the most? And of his sons, whom he had not known, did Jacob love the
# PEFT Model Answer: Which of his wives did Jacob love the most? And of his sons? And of his daughters? And of his concub
# ------------------
#
#
# ------------------
# QUESTION 199
# Question: What is the name of Jesus' cousin born six months before him?
# Answer: John
# Pre-trained Model Answer: What is the name of Jesus' cousin born six months before him?
#
# The name of Jesus' cousin is Joseph.
#
# The name
# Fine-tuned Model Answer: What is the name of Jesus' cousin born six months before him? And what is the name of his mother? And what is the name of
# PEFT Model Answer: What is the name of Jesus' cousin born six months before him? John the Baptist. And what is the name of his brother born six months
# ------------------
#
#
# ------------------
# QUESTION 220
# Question: What was Solomon famous for building?
# Answer: Temple
# Pre-trained Model Answer: What was Solomon famous for building?
#
# Solomon was famous for building the Temple of Solomon. He was
# Fine-tuned Model Answer: What was Solomon famous for building? For his house was the house of Jehovah, and his throne the throne of
# PEFT Model Answer: What was Solomon famous for building?
#
# The temple of Solomon was the house of God.
#
# The
# ------------------
#
#
# ------------------
# QUESTION 315
# Question: Which tribe followed David after the split of the Kingdom of Israel?
# Answer: Judah
# Pre-trained Model Answer: Which tribe followed David after the split of the Kingdom of Israel?
#
# The tribe of Judah.
#
# The tribe of Benjamin followed David
# Fine-tuned Model Answer: Which tribe followed David after the split of the Kingdom of Israel? And the tribe of Judah followed after David after the split of the kingdom of
# PEFT Model Answer: Which tribe followed David after the split of the Kingdom of Israel?
#
# And the tribe of Judah?
#
# And the tribe of Benjamin
# ------------------
#
#
# ------------------
# QUESTION 336
# Question: Which city did David pray for the peace of?
# Answer: Jerusalem
# Pre-trained Model Answer: Which city did David pray for the peace of?
#
# The answer is: Jerusalem.
#
# The Bible says that David
# Fine-tuned Model Answer: Which city did David pray for the peace of? And David said, Jerusalem. And David said, I will pray for thee
# PEFT Model Answer: Which city did David pray for the peace of? The city of David, the city of David, the city of David,
# ------------------
#
#
# ------------------
# QUESTION 349
# Question: In which city was David's throne over Israel?
# Answer: Jerusalem
# Pre-trained Model Answer: In which city was David's throne over Israel?
#
# The Bible says that David was the king of Israel.
#
#
# Fine-tuned Model Answer: In which city was David's throne over Israel? And where was the house of David? And where was the house of David
# PEFT Model Answer: In which city was David's throne over Israel? And he reigned in Jerusalem. And he reigned over Israel for thirty
# ------------------
#
#
# ------------------
# QUESTION 354
# Question: Which king built the first temple in Jerusalem?
# Answer: Solomon
# Pre-trained Model Answer: Which king built the first temple in Jerusalem?
#
# The answer is:
#
# The first temple was built by Solomon
# Fine-tuned Model Answer: Which king built the first temple in Jerusalem? And who built the second temple in Jerusalem? And who built the third temple
# PEFT Model Answer: Which king built the first temple in Jerusalem?
#
# A king of Judah.
#
# A king of Judah.
#
# ------------------
#
#
# ------------------
# QUESTION 378
# Question: Where were the Jews taken captive to when Jerusalem was destroyed?
# Answer: Babylon
# Pre-trained Model Answer: Where were the Jews taken captive to when Jerusalem was destroyed?
#
# The Jews were taken captive to Babylon, and the Babylonians were
# Fine-tuned Model Answer: Where were the Jews taken captive to when Jerusalem was destroyed? And the priests and the Levites were taken captive to when the children of
# PEFT Model Answer: Where were the Jews taken captive to when Jerusalem was destroyed? And they said unto him, We have no knowledge of the captivity of the
# ------------------
#
#
# ------------------
# QUESTION 402
# Question: On what island was John when he was given the vision of Revelation?
# Answer: Patmos
# Pre-trained Model Answer: On what island was John when he was given the vision of Revelation?
#
# John was on the island of Patmos, which is in the
# Fine-tuned Model Answer: On what island was John when he was given the vision of Revelation? And he said unto them, I am the first and the last, and
# PEFT Model Answer: On what island was John when he was given the vision of Revelation? On the island of Patmos. And what was the island of Patmos
# ------------------
#
#
# ------------------
# QUESTION 433
# Question: Who prayed for the fiery serpents to be taken away from Israel?
# Answer: Moses
# Pre-trained Model Answer: Who prayed for the fiery serpents to be taken away from Israel?
#
# The Lord said to Moses, "I am the Lord your God
# Fine-tuned Model Answer: Who prayed for the fiery serpents to be taken away from Israel? And the children of Israel did eat the flesh of the slain of the children
# PEFT Model Answer: Who prayed for the fiery serpents to be taken away from Israel? And the Lord said unto Moses, Go to Pharaoh, and say unto him
# ------------------
#
#
# ------------------
# QUESTION 501
# Question: How many churches of Asia Minor were listed in Revelation?
# Answer: Seven
# Pre-trained Model Answer: How many churches of Asia Minor were listed in Revelation?
#
# The number of churches in Asia Minor is not known. The number
# Fine-tuned Model Answer: How many churches of Asia Minor were listed in Revelation? And how many churches of the Jews were there in the land of the Ch
# PEFT Model Answer: How many churches of Asia Minor were listed in Revelation?
#
# A. Seven.
#
# B. Seven.
#
# C
# ------------------
#
#
# ------------------
# QUESTION 503
# Question: In which city in Judah did Cyrus tell the Israelites to build the temple?
# Answer: Jerusalem
# Pre-trained Model Answer: In which city in Judah did Cyrus tell the Israelites to build the temple?
#
# The answer is in the Bible.
#
# The temple was built
# Fine-tuned Model Answer: In which city in Judah did Cyrus tell the Israelites to build the temple? and in which city in Jerusalem did Cyrus tell the Israelites to build the
# PEFT Model Answer: In which city in Judah did Cyrus tell the Israelites to build the temple? And they built it in the second year of king Nebuchadrezz
# ------------------
#
#
# ------------------
# QUESTION 521
# Question: What nationality was Timothy's father?
# Answer: Greek
# Pre-trained Model Answer: What nationality was Timothy's father?
#
# The answer is that he was a German.
#
# The German
# Fine-tuned Model Answer: What nationality was Timothy's father? And what was his mother? And what was his mother’s name
# PEFT Model Answer: What nationality was Timothy's father?
#
# A. The son of a Greek.
#
# Q. What
# ------------------
#
#
# ------------------
# QUESTION 563
# Question: What was the name of the father of Caleb the spy?
# Answer: Jephunneh
# Pre-trained Model Answer: What was the name of the father of Caleb the spy?
#
# Caleb was the son of a man named Caleb, who was
# Fine-tuned Model Answer: What was the name of the father of Caleb the spy? And the name of the father of Jephunneh? And the
# PEFT Model Answer: What was the name of the father of Caleb the spy? He was called Caleb the son of Jotham.
#
# And the
# ------------------
#
#
# ------------------
# QUESTION 611
# Question: Who was the king of Judea at the time of Jesus' birth?
# Answer: Herod
# Pre-trained Model Answer: Who was the king of Judea at the time of Jesus' birth?
#
# The Bible says that Jesus was born in Bethlehem of Judea,
# Fine-tuned Model Answer: Who was the king of Judea at the time of Jesus' birth? And who was the king of Jerusalem at the time of his death? And
# PEFT Model Answer: Who was the king of Judea at the time of Jesus' birth? Jesus was born in Bethlehem of Judea. Herod the king was his father
# ------------------
#
#
# ------------------
# QUESTION 631
# Question: On which island did Paul preach on his first missionary journey?
# Answer: Cyprus
# Pre-trained Model Answer: On which island did Paul preach on his first missionary journey?
#
# Paul's first missionary journey was to the island of Cyprus. He
# Fine-tuned Model Answer: On which island did Paul preach on his first missionary journey? And where did he preach? And where was he? And where was he
# PEFT Model Answer: On which island did Paul preach on his first missionary journey? On the island of Cyprus. And what did he preach there? On the
# ------------------
#
#
# ------------------
# QUESTION 668
# Question: Which of the twelve sons of Jacob had a name that means "praise"?
# Answer: Judah
# Pre-trained Model Answer: Which of the twelve sons of Jacob had a name that means "praise"?
#
# The answer is Jacob.
#
# Jacob was the firstborn son
# Fine-tuned Model Answer: Which of the twelve sons of Jacob had a name that means "praise"? and the name of the first-born of the tribe of Judah was J
# PEFT Model Answer: Which of the twelve sons of Jacob had a name that means "praise"? For the name of the first son of Jacob was Abijah, and the
# ------------------
#
#
# ------------------
# QUESTION 705
# Question: Where was David born?
# Answer: Bethlehem
# Pre-trained Model Answer: Where was David born?
#
# David was born in the city of David, in the land of
# Fine-tuned Model Answer: Where was David born? And where was the house of Jehovah? And where was the tabernacle
# PEFT Model Answer: Where was David born? In Bethlehem of Judea, in the land of the Philistines.
# ------------------
#
#
# ------------------
# QUESTION 850
# Question: Which nation does Jeremiah say is dwelling in Gad?
# Answer: Ammon
# Pre-trained Model Answer: Which nation does Jeremiah say is dwelling in Gad?
#
# Jeremiah 1:1 ESV / 4 helpful votes Helpful Not Helpful
# Fine-tuned Model Answer: Which nation does Jeremiah say is dwelling in Gad? And he said, The children of Ammon. And he said, The
# PEFT Model Answer: Which nation does Jeremiah say is dwelling in Gad? And what is the name of the city? And what is the name of
# ------------------

# %% [markdown]
# Finally, we calculate the accuracy of each model, also providing absolute number of questions correct.

# %%
pretrained_accuracy = pretrained_correct / len(bible_qa_rows)
fine_tuned_accuracy = fine_tuned_correct / len(bible_qa_rows)
peft_accuracy = peft_correct / len(bible_qa_rows)

print(f'Pre-trained Model Accuracy: {pretrained_accuracy} ' +\
      f'({pretrained_correct}/{len(bible_qa_rows)})')
print(f'Fine-tuned Model Accuracy: {fine_tuned_accuracy} ' +\
      f'({fine_tuned_correct}/{len(bible_qa_rows)})')
print(f'PEFT Model Accuracy: {peft_accuracy} ' +\
      f'({peft_correct}/{len(bible_qa_rows)})')
# Out:
# Pre-trained Model Accuracy: 0.023702031602708805 (21/886)
# Fine-tuned Model Accuracy: 0.013544018058690745 (12/886)
# PEFT Model Accuracy: 0.019187358916478554 (17/886)
