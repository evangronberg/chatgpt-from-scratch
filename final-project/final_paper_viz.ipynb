# %%
import seaborn as sns

# %%
fine_tuning_losses = [
    2.664100,
    2.504100,
    2.457900,
    2.410900,
    2.358000,
    2.326700,
    2.311500,
    2.147500,
    1.796300,
    1.796400,
    1.771900,
    1.791400,
    1.779900,
    1.767000,
    1.752900,
    1.536300,
    1.296600,
    1.305000,
    1.306800,
    1.309100,
    1.299800,
    1.295000,
    1.287400,
    1.072000,
    0.968200,
    0.966400,
    0.979500,
    0.967500,
    0.972800,
    0.957200,
    0.958800
]
fine_tuning_losses_df = {
    'Step': [500 * (i+1) for i in range(len(fine_tuning_losses))],
    'Loss': fine_tuning_losses
}
peft_losses = [
    2.887600,
    2.552200,
    2.526600,
    2.502200,
    2.481800,
    2.468300,
    2.480800,
    2.443600,
    2.454800,
    2.441800,
    2.412300,
    2.423100,
    2.422700,
    2.411200,
    2.407500,
    2.392800,
    2.413500,
    2.399600,
    2.399700,
    2.397300,
    2.391800,
    2.391600,
    2.366500,
    2.378000,
    2.374400,
    2.363700,
    2.382200,
    2.374500,
    2.374900,
    2.364300,
    2.370300,
]
peft_losses_df = {
    'Step': [500 * (i+1) for i in range(len(peft_losses))],
    'Loss': peft_losses
}

# %%
fine_tuning_line_plot = sns.lineplot(fine_tuning_losses_df, x='Step', y='Loss')
fine_tuning_line_plot.set_title('Fine-Tuning Model Loss')
fine_tuning_line_plot
# Out:
# <Axes: title={'center': 'Fine-Tuning Model Loss'}, xlabel='Step', ylabel='Loss'>

# %%
peft_line_plot = sns.lineplot(peft_losses_df, x='Step', y='Loss')
peft_line_plot.set_title('PEFT Model Loss')
peft_line_plot
# Out:
# <Axes: title={'center': 'PEFT Model Loss'}, xlabel='Step', ylabel='Loss'>
