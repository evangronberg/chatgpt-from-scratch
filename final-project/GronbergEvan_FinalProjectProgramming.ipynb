# %% [markdown]
# # Fine-Tuning on Pre-Training Data: A Performance Comparison
#
# In this notebook, we fine-tune a large language model (LLM) on the Bible (using both standard and parameter-efficient fine-tuning) and evaluate any potential performance increase on the BibleQA dataset.
#
# To start, we install and import our necessary dependencies.

# %%
# !pip install transformers datasets peft pandas tqdm
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Collecting datasets
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Collecting peft
#   Downloading peft-0.12.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.3.1+cu121)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from peft) (0.32.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.13.0->peft)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.13.0->peft)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.13.0->peft)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.13.0->peft)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.13.0->peft)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.13.0->peft)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.13.0->peft)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.13.0->peft)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.13.0->peft)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.13.0->peft)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.13.0->peft)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 28.5 MB/s eta 0:00:00
# Downloading peft-0.12.0-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 24.3 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.1 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 49.1 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 51.9 kB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.7 MB/s eta 0:00:00
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Installing collected packages: xxhash, pyarrow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, peft
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed datasets-2.21.0 dill-0.3.8 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 peft-0.12.0 pyarrow-17.0.0 xxhash-3.5.0

# %%
import csv
import pandas as pd
from tqdm import tqdm
from datasets import load_dataset
from peft import get_peft_model, LoraConfig
from transformers import (
    AutoTokenizer, AutoModelForCausalLM,
    Trainer, TrainingArguments,
    DataCollatorForLanguageModeling
)
N_FINE_TUNING_EPOCHS = 4

# %% [markdown]
# Next, we load in the biblical text as a Hugging Face dataset for later fine-tuning.

# %%
bible_text_dataset = load_dataset('text', data_files={'train': 'bible.txt'})
bible_text_dataset
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 31104
#     })
# })

# %% [markdown]
# Before proceeding, we print a sample from the Bible dataset as a sanity check.

# %%
bible_text_dataset['train'][3000]['text']
# Out:
# 'Leviticus 11:1\tAnd Jehovah spake unto Moses and to Aaron, saying unto them,'

# %% [markdown]
# We now prepare our BibleQA dataset as question-answer pairs and display a sample.

# %%
bible_qa_pairs = {
    'questions': [],
    'answers': []
}
with open('bible_qa_pairs.csv') as bible_qa_pairs_csv_file:
    bible_qa_csv_file_reader = csv.reader(bible_qa_pairs_csv_file, delimiter='\t')
    header = next(bible_qa_csv_file_reader)
    for row in bible_qa_csv_file_reader:
        if row:
            bible_qa_pairs['questions'].append(
                ''.join(row[0].split('. ')[1:]))
            bible_qa_pairs['answers'].append(
                ''.join(''.join(row[1].split('. ')[1:]).split(' (')[:1]))
bible_qa_pairs_df = pd.DataFrame(bible_qa_pairs)
bible_qa_pairs_df.head()
# Out:
#                                            questions  \
# 0                What was the name of Jesus' mother?
# 1  What was the name of the garden where Adam and...
# 2       With what food did Jesus feed the multitude?
# 3      What method did the Romans use to kill Jesus?
# 4  From which part of Adam's body did God create ...
#
#                       answers
# 0                        Mary
# 1                        Eden
# 2  Five loaves and two fishes
# 3                 Crucifixion
# 4                         Rib

# %% [markdown]
# We should now load in both our models and our tokenizer. In the case of the former, we load in three instances of the model, one for each of our evaluations.

# %%
model_name = 'openai-community/gpt2-large'
pretrained_model = AutoModelForCausalLM.from_pretrained(model_name)
fine_tuned_model = AutoModelForCausalLM.from_pretrained(model_name)
peft_model = AutoModelForCausalLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# Now that we have our tokenizer, we can tokenize our biblical text for fine-tuning.

# %%
def tokenize_bible_text(examples):
    return tokenizer(
        examples['text'], truncation=True,
        padding='max_length', max_length=512
    )
tokenized_bible_text = bible_text_dataset.map(
    tokenize_bible_text, batched=True
)
# Out:
# Map:   0%|          | 0/31104 [00:00<?, ? examples/s]

# %% [markdown]
# Fine-tuning can now take place. We first fine-tune in a straightforward fashion, simply performing more training but with our specific data.

# %%
# On A100: ~1.5 hr/epoch
fined_tuned_data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)
fine_tuned_training_args = TrainingArguments(
    output_dir='./fine_tuning_results',
    overwrite_output_dir=True,
    num_train_epochs=N_FINE_TUNING_EPOCHS,
    per_device_train_batch_size=8,
    save_strategy='no'
)
fine_tuned_trainer = Trainer(
    model=fine_tuned_model,
    args=fine_tuned_training_args,
    train_dataset=tokenized_bible_text['train'],
    data_collator=fined_tuned_data_collator
)
fine_tuned_trainer.train()
# Out:
#     <div>
#
#       <progress value='15552' max='15552' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [15552/15552 5:44:47, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>2.664100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>2.504100</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>2.457900</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.410900</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2.358000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.326700</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>2.311500</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>2.147500</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>1.796300</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>1.796400</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>1.771900</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>1.791400</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>1.779900</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>1.767000</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>1.752900</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>1.536300</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>1.296600</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>1.305000</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>1.306800</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>1.309100</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>1.299800</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>1.295000</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>1.287400</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>1.072000</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.968200</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.966400</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.979500</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.967500</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.972800</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.957200</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.958800</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=15552, training_loss=1.6144247307698913, metrics={'train_runtime': 20690.7961, 'train_samples_per_second': 6.013, 'train_steps_per_second': 0.752, 'total_flos': 2.707510272196608e+17, 'train_loss': 1.6144247307698913, 'epoch': 4.0})

# %% [markdown]
# Next, we perform parameter-efficient fine-tuning (PEFT) in the form of low-rank adaptation (LoRA).

# %%
# On A100: ~1.0 hr/epoch
lora_config = LoraConfig(
    r=16,
    lora_alpha=16,
    target_modules=['c_attn', 'c_proj']
)
peft_model = get_peft_model(peft_model, lora_config)

peft_data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)
peft_training_args = TrainingArguments(
    output_dir='./peft_results',
    overwrite_output_dir=True,
    num_train_epochs=N_FINE_TUNING_EPOCHS,
    per_device_train_batch_size=8,
    save_strategy='no'
)
peft_trainer = Trainer(
    model=peft_model,
    args=peft_training_args,
    train_dataset=tokenized_bible_text['train'],
    data_collator=peft_data_collator
)
peft_trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/tuners/lora/layer.py:1091: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(
#     <div>
#
#       <progress value='15552' max='15552' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [15552/15552 4:17:14, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>2.887600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>2.552200</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>2.526600</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.502200</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2.481800</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.468300</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>2.480800</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>2.443600</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>2.454800</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>2.441800</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>2.412300</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>2.423100</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>2.422700</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>2.411200</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>2.407500</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>2.392800</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>2.413500</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>2.399600</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>2.399700</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>2.397300</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>2.391800</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>2.391600</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>2.366500</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>2.378000</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>2.374400</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>2.363700</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>2.382200</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>2.374500</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>2.374900</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>2.364300</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>2.370300</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=15552, training_loss=2.4338112740850253, metrics={'train_runtime': 15435.6276, 'train_samples_per_second': 8.06, 'train_steps_per_second': 1.008, 'total_flos': 2.7385074806685696e+17, 'train_loss': 2.4338112740850253, 'epoch': 4.0})

# %% [markdown]
# Finally, we can evaluate our models on the question-answer pairs. Note that we embed our questions into a few-shot learning prompt to encourage the text-continuation model to output answers to the question (we also explicitly inform the model of the biblical nature of the questions).

# %%
def generate_answer(model: AutoModelForCausalLM, question: str) -> str:
    if not question.strip():
        return ''

    prompt =\
    f'The following are questions and answers about the Bible.\n\n\
Q: Who was the first man?\n\
A: Adam\n\n\
Q: What was special about Samson?\n\
A: He was very strong\n\n\
Q: Where was Jesus born?\n\
A: Bethlehem\n\n\
Q: {question}\n\
A: '
    input_tokens = tokenizer.encode(
        question,
        return_tensors='pt'
    ).to(model.device)
    attention_mask = input_tokens.ne(
        tokenizer.pad_token_id
    ).to(model.device)
    model_output = model.generate(
        input_tokens,
        max_new_tokens=15,
        num_return_sequences=1,
        pad_token_id=tokenizer.eos_token_id,
        attention_mask=attention_mask
    )
    answer = tokenizer.decode(
        model_output[0],
        skip_special_tokens=True
    )
    answer = answer.replace(prompt, '')
    return answer

# %%
pretrained_model_answers = []
fine_tuned_model_answers = []
peft_model_answers = []
for question in tqdm(bible_qa_pairs_df['questions']):
    pretrained_model_answers.append(
        generate_answer(pretrained_model, question))
    fine_tuned_model_answers.append(
        generate_answer(fine_tuned_model, question))
    peft_model_answers.append(
        generate_answer(peft_model, question))

bible_qa_pairs_df['pretrained_model_answers'] = pretrained_model_answers
bible_qa_pairs_df['fine_tuned_model_answers'] = fine_tuned_model_answers
bible_qa_pairs_df['peft_model_answers'] = peft_model_answers
# Out:
# 100%|██████████| 886/886 [34:29<00:00,  2.34s/it]

# %%
pretrained_correct = 0
fine_tuned_correct = 0
peft_correct = 0
bible_qa_rows = bible_qa_pairs_df.to_dict(orient='records')
for row in bible_qa_rows:
    one_correct = False
    if row['answers'] in row['pretrained_model_answers']:
        pretrained_correct += 1
        one_correct = True
    if row['answers'] in row['fine_tuned_model_answers']:
        fine_tuned_correct += 1
        one_correct = True
    if row['answers'] in row['peft_model_answers']:
        peft_correct += 1
        one_correct = True
    if one_correct:
        print(f'Question: {row["questions"]}')
        print(f'Answer: {row["answers"]}')
        print(f'Pre-trained Model Answer: {row["pretrained_model_answers"]}')
        print(f'Fine-tuned Model Answer: {row["fine_tuned_model_answers"]}')
        print(f'PEFT Model Answer: {row["peft_model_answers"]}')
        print()

pretrained_accuracy = pretrained_correct / len(bible_qa_rows)
fine_tuned_accuracy = fine_tuned_correct / len(bible_qa_rows)
peft_accuracy = peft_correct / len(bible_qa_rows)

print(f'Pre-trained Model Accuracy: {pretrained_accuracy}')
print(f'Fine-tuned Model Accuracy: {fine_tuned_accuracy}')
print(f'PEFT Model Accuracy: {peft_accuracy}')
# Out:
# Question: What was the name of Jesus' mother?
# Answer: Mary
# Pre-trained Model Answer: What was the name of Jesus' mother?
#
# The name of Jesus' mother was Mary.
#
# Was Jesus
# Fine-tuned Model Answer: What was the name of Jesus' mother? Elisabeth, of the family of the Elisabethites; and
# PEFT Model Answer: What was the name of Jesus' mother? And what was the name of his father? And what was the name of
#
# Question: What was the name of the garden where Adam and Eve lived?
# Answer: Eden
# Pre-trained Model Answer: What was the name of the garden where Adam and Eve lived?
#
# The Garden of Eden.
#
# What was the name of the
# Fine-tuned Model Answer: What was the name of the garden where Adam and Eve lived? The name of the garden was called Cana of Galilee. And the
# PEFT Model Answer: What was the name of the garden where Adam and Eve lived? And what was the name of the first tree which they sowed? And
#
# Question: What was special about Jesus' mother?
# Answer: She was a virgin
# Pre-trained Model Answer: What was special about Jesus' mother?
#
# The Bible says that Jesus' mother was a virgin.
#
#
# Fine-tuned Model Answer: What was special about Jesus' mother? And they said, The woman was a Greek, a Syrophoenician
# PEFT Model Answer: What was special about Jesus' mother? She was a virgin. What was special about her? She was a virgin
#
# Question: To which city did God ask Jonah to take his message?
# Answer: Nineveh
# Pre-trained Model Answer: To which city did God ask Jonah to take his message?
#
# The answer is, of course, Jerusalem.
#
# The city
# Fine-tuned Model Answer: To which city did God ask Jonah to take his message? and where was he when God sent him? and what was the message which
# PEFT Model Answer: To which city did God ask Jonah to take his message? And he said, The city of Nineveh. And God said, Nine
#
# Question: Who was David's father?
# Answer: Jesse
# Pre-trained Model Answer: Who was David's father?
#
# David's father was a man named David. He was a farmer
# Fine-tuned Model Answer: Who was David's father? was he not the son of Jesse, David’s father? and
# PEFT Model Answer: Who was David's father? And who was his mother? And who was his wife? And who was
#
# Question: What was the name of Moses' brother?
# Answer: Aaron
# Pre-trained Model Answer: What was the name of Moses' brother?
#
# Moses was the brother of Aaron, the brother of Levi,
# Fine-tuned Model Answer: What was the name of Moses' brother? And he said, Aaron. And Moses was stedfast in his calling
# PEFT Model Answer: What was the name of Moses' brother? And what was the name of his wife? And what was the name of
#
# Question: From which country did Moses help the Israelites escape from their lives of slavery?
# Answer: Egypt
# Pre-trained Model Answer: From which country did Moses help the Israelites escape from their lives of slavery?
#
# Moses was born in Egypt, and his father was a Pharaoh
# Fine-tuned Model Answer: From which country did Moses help the Israelites escape from their lives of slavery? from Egypt. And Moses said, I will go up thither, and
# PEFT Model Answer: From which country did Moses help the Israelites escape from their lives of slavery? From Egypt. And Moses said unto Pharaoh, I will not go up with
#
# Question: What was the name of the tower that the people were building when God confused their language?
# Answer: Tower of Babel
# Pre-trained Model Answer: What was the name of the tower that the people were building when God confused their language?
#
# The tower was called "The Tower of Babel" because it was
# Fine-tuned Model Answer: What was the name of the tower that the people were building when God confused their language? And they said, The watchtower of the camp of Jehovah. And they
# PEFT Model Answer: What was the name of the tower that the people were building when God confused their language? And the people said, We are building a tower to the east of the
#
# Question: Which sea did the Israelites cross through to escape the Egyptians?
# Answer: Red Sea
# Pre-trained Model Answer: Which sea did the Israelites cross through to escape the Egyptians?
#
# The Israelites crossed the Red Sea to escape the Egyptians.
#
# Fine-tuned Model Answer: Which sea did the Israelites cross through to escape the Egyptians? And where did they eat the most holy things of the children of Israel,
# PEFT Model Answer: Which sea did the Israelites cross through to escape the Egyptians? And the Egyptians were not able to destroy them. And the Egyptians said,
#
# Question: What was the name of Abraham's first wife?
# Answer: Sarah
# Pre-trained Model Answer: What was the name of Abraham's first wife?
#
# Abraham was the father of Isaac and of Jacob.
#
#
# Fine-tuned Model Answer: What was the name of Abraham's first wife? Mahlah, in the day that he offered Isaac his first-born for
# PEFT Model Answer: What was the name of Abraham's first wife? Is it Sarah? Is it Sarah the wife of Abraham? Is it Sarah
#
# Question: Who was Solomon's father?
# Answer: David
# Pre-trained Model Answer: Who was Solomon's father?
#
# Solomon's father was Solomon, the son of David.
#
# Fine-tuned Model Answer: Who was Solomon's father? And who was the son of David? And who was the son of Solomon
# PEFT Model Answer: Who was Solomon's father? And what was Solomon's mother? And what was Solomon's brother? And
#
# Question: Abraham's wife Sarah bore a special sonWhat was his name?
# Answer: Isaac
# Pre-trained Model Answer: Abraham's wife Sarah bore a special sonWhat was his name? Abraham's son Isaac.
#
# Abraham's wife Sarah bore a special
# Fine-tuned Model Answer: Abraham's wife Sarah bore a special sonWhat was his name? Abraham’s servant was he.And he was the father of Isaac
# PEFT Model Answer: Abraham's wife Sarah bore a special sonWhat was his name? Ishmael. And he was the father of Ishmael the son
#
# Question: Which garden did Jesus go to to pray in before his arrest?
# Answer: Gethsemane
# Pre-trained Model Answer: Which garden did Jesus go to to pray in before his arrest?
#
# The Garden of Gethsemane.
#
# The Garden
# Fine-tuned Model Answer: Which garden did Jesus go to to pray in before his arrest? And he said, To-day I am going to pray to my Father
# PEFT Model Answer: Which garden did Jesus go to to pray in before his arrest?
#
# Luke 6:21	And he said, I am not yet
#
# Question: To which country did Mary and Joseph escape when Herod killed all the babies in Bethlehem?
# Answer: Egypt
# Pre-trained Model Answer: To which country did Mary and Joseph escape when Herod killed all the babies in Bethlehem?
#
# The answer is that they escaped to Egypt.
#
# The Bible
# Fine-tuned Model Answer: To which country did Mary and Joseph escape when Herod killed all the babies in Bethlehem? did they not flee from the face of Herod? And where are the two
# PEFT Model Answer: To which country did Mary and Joseph escape when Herod killed all the babies in Bethlehem? And where is the tomb of the Lord? And where is the sepul
#
# Question: What is the name of the angel who appeared to Mary?
# Answer: Gabriel
# Pre-trained Model Answer: What is the name of the angel who appeared to Mary?
#
# Answer: The angel who appeared to Mary was the angel Gabriel.
# Fine-tuned Model Answer: What is the name of the angel who appeared to Mary? The same is the name of the Lord God. And the angel said unto
# PEFT Model Answer: What is the name of the angel who appeared to Mary? And what is the name of the angel who appeared to Joseph? And what
#
# Question: Which land did the Lord promise to Abram?
# Answer: Canaan
# Pre-trained Model Answer: Which land did the Lord promise to Abram?
#
# Abram was a descendant of Ham, and his father was a
# Fine-tuned Model Answer: Which land did the Lord promise to Abram? And he said, The land of Canaan. And he said, The land
# PEFT Model Answer: Which land did the Lord promise to Abram? And he said, The land of Canaan. And he said, I will
#
# Question: On what mountain did Moses receive the law from God?
# Answer: Mount Sinai
# Pre-trained Model Answer: On what mountain did Moses receive the law from God?
#
# Moses received the law from God on Mount Sinai.
#
#
# Fine-tuned Model Answer: On what mountain did Moses receive the law from God? And where was the fountain of Moses? And where was the place of the
# PEFT Model Answer: On what mountain did Moses receive the law from God? From the mount of Sinai. And he said, This mountain is the mount
#
# Question: Which of his wives did Jacob love the most?
# Answer: Rachel
# Pre-trained Model Answer: Which of his wives did Jacob love the most?
#
# Jacob's answer:
#
# "I love Rachel more than all
# Fine-tuned Model Answer: Which of his wives did Jacob love the most? and of his wives whom he had in the days of his life, whom
# PEFT Model Answer: Which of his wives did Jacob love the most? And Jacob said, I love Rachel, and Leah my wife, and Leah
#
# Question: What is the name of Jesus' cousin born six months before him?
# Answer: John
# Pre-trained Model Answer: What is the name of Jesus' cousin born six months before him?
#
# The name of Jesus' cousin is Joseph.
#
# The name
# Fine-tuned Model Answer: What is the name of Jesus' cousin born six months before him? This was the son of a woman of the village of Mary and her mother
# PEFT Model Answer: What is the name of Jesus' cousin born six months before him? And he was called John the Baptist. And he was a disciple of Jesus
#
# Question: What was Solomon famous for building?
# Answer: Temple
# Pre-trained Model Answer: What was Solomon famous for building?
#
# Solomon was famous for building the Temple of Solomon. He was
# Fine-tuned Model Answer: What was Solomon famous for building? For he was the son of David, and his mother was Elisabeth
# PEFT Model Answer: What was Solomon famous for building? For he built the house of God, and the house of the Lord,
#
# Question: Which river was Naaman told to wash in to rid himself of leprosy?
# Answer: Jordan
# Pre-trained Model Answer: Which river was Naaman told to wash in to rid himself of leprosy?
#
# The answer is: the Nile.
#
# The Nile is the
# Fine-tuned Model Answer: Which river was Naaman told to wash in to rid himself of leprosy? And the water of the river was sweet to him, and he was clean
# PEFT Model Answer: Which river was Naaman told to wash in to rid himself of leprosy? And he washed in the river of the Jordan, and the leprosy
#
# Question: What was the name of James' and John's father?
# Answer: Zebedee
# Pre-trained Model Answer: What was the name of James' and John's father?
#
# "James and John's father was a man named John. He
# Fine-tuned Model Answer: What was the name of James' and John's father? And they said, The sons of Zebedee, of the tribe
# PEFT Model Answer: What was the name of James' and John's father? And what was the name of his mother? And what was the name of
#
# Question: Which wise man wrote the majority of Proverbs?
# Answer: Solomon
# Pre-trained Model Answer: Which wise man wrote the majority of Proverbs?
#
# The answer is that the wise man was not a prophet. He
# Fine-tuned Model Answer: Which wise man wrote the majority of Proverbs? And who wrote the proverbs of Solomon better than I? And who drew
# PEFT Model Answer: Which wise man wrote the majority of Proverbs? For he that is wise is not a fool, but a wise man.
#
# Question: What was the name of Solomon's son who succeeded him as king?
# Answer: Rehoboam
# Pre-trained Model Answer: What was the name of Solomon's son who succeeded him as king?
#
# "The son of David, the son of Jesse, the son
# Fine-tuned Model Answer: What was the name of Solomon's son who succeeded him as king? And the name of his son was Rehoboam. And Solomon�
# PEFT Model Answer: What was the name of Solomon's son who succeeded him as king? And Solomon said unto him, What is the name of the son of the
#
# Question: The king's wrath is as "the roaring" of what?
# Answer: A lion
# Pre-trained Model Answer: The king's wrath is as "the roaring" of what?
#
# The king's wrath is as "the roaring" of what?
# Fine-tuned Model Answer: The king's wrath is as "the roaring" of what? A lion, or a bear? And the king’s anger is
# PEFT Model Answer: The king's wrath is as "the roaring" of what? The king is a roaring lion, and the king is a roaring lion.
#
# Question: Which tribe followed David after the split of the Kingdom of Israel?
# Answer: Judah
# Pre-trained Model Answer: Which tribe followed David after the split of the Kingdom of Israel?
#
# The tribe of Judah.
#
# The tribe of Benjamin followed David
# Fine-tuned Model Answer: Which tribe followed David after the split of the Kingdom of Israel? (The same is Beth-el.) And the tribe of the children of
# PEFT Model Answer: Which tribe followed David after the split of the Kingdom of Israel? And David was a son of Jesse. And David was a man of great
#
# Question: Which city did David pray for the peace of?
# Answer: Jerusalem
# Pre-trained Model Answer: Which city did David pray for the peace of?
#
# The answer is: Jerusalem.
#
# The Bible says that David
# Fine-tuned Model Answer: Which city did David pray for the peace of? From the midst of the children of Israel came he forth to pray for the
# PEFT Model Answer: Which city did David pray for the peace of? And what was the name of the city? For the name of the city
#
# Question: Which king built the first temple in Jerusalem?
# Answer: Solomon
# Pre-trained Model Answer: Which king built the first temple in Jerusalem?
#
# The answer is:
#
# The first temple was built by Solomon
# Fine-tuned Model Answer: Which king built the first temple in Jerusalem? And the answer of the two men was, That king David dedicated the first
# PEFT Model Answer: Which king built the first temple in Jerusalem? And which king built the second temple in Jerusalem? And which king built the
#
# Question: Where were the Jews taken captive to when Jerusalem was destroyed?
# Answer: Babylon
# Pre-trained Model Answer: Where were the Jews taken captive to when Jerusalem was destroyed?
#
# The Jews were taken captive to Babylon, and the Babylonians were
# Fine-tuned Model Answer: Where were the Jews taken captive to when Jerusalem was destroyed? Were they taken captive to the house of David? Were they taken captive to
# PEFT Model Answer: Where were the Jews taken captive to when Jerusalem was destroyed? And what was the number of the captives that were taken? And what was
#
# Question: On what island was John when he was given the vision of Revelation?
# Answer: Patmos
# Pre-trained Model Answer: On what island was John when he was given the vision of Revelation?
#
# John was on the island of Patmos, which is in the
# Fine-tuned Model Answer: On what island was John when he was given the vision of Revelation? From thence cometh the sound of the sea, and the voice of the
# PEFT Model Answer: On what island was John when he was given the vision of Revelation? And where was he when he saw the angel of the Lord? And where
#
# Question: Who prayed for the fiery serpents to be taken away from Israel?
# Answer: Moses
# Pre-trained Model Answer: Who prayed for the fiery serpents to be taken away from Israel?
#
# The Lord said to Moses, "I am the Lord your God
# Fine-tuned Model Answer: Who prayed for the fiery serpents to be taken away from Israel? And they were taken away from among the nations. And Moses was wroth
# PEFT Model Answer: Who prayed for the fiery serpents to be taken away from Israel? And they were not taken away. And they were not taken away. And
#
# Question: In which city in Judah did Cyrus tell the Israelites to build the temple?
# Answer: Jerusalem
# Pre-trained Model Answer: In which city in Judah did Cyrus tell the Israelites to build the temple?
#
# The answer is in the Bible.
#
# The temple was built
# Fine-tuned Model Answer: In which city in Judah did Cyrus tell the Israelites to build the temple? and in which city was he a father to them that were born in Israel
# PEFT Model Answer: In which city in Judah did Cyrus tell the Israelites to build the temple? And they said, In the city of Jerusalem. And he said unto them
#
# Question: What was the name of the man who requested Jesus' body for burial?
# Answer: Joseph
# Pre-trained Model Answer: What was the name of the man who requested Jesus' body for burial?
#
# The man who requested Jesus' body for burial was a man named
# Fine-tuned Model Answer: What was the name of the man who requested Jesus' body for burial? And they said, The son of Joseph. And when they had said this
# PEFT Model Answer: What was the name of the man who requested Jesus' body for burial? And Jesus said unto him, Who art thou? And he said, I
#
# Question: What was the name of the father of Caleb the spy?
# Answer: Jephunneh
# Pre-trained Model Answer: What was the name of the father of Caleb the spy?
#
# Caleb was the son of a man named Caleb, who was
# Fine-tuned Model Answer: What was the name of the father of Caleb the spy? And the sons of Caleb the son of Jephunneh: She
# PEFT Model Answer: What was the name of the father of Caleb the spy? And the name of the mother of Caleb the spy? She was called Ner
#
# Question: Who was the goddess of the Ephesians?
# Answer: Diana
# Pre-trained Model Answer: Who was the goddess of the Ephesians?
#
# The goddess of the Ephesians was the goddess of the Ep
# Fine-tuned Model Answer: Who was the goddess of the Ephesians? And was not the goddess of the Egyptians Diana, the daughter of the god
# PEFT Model Answer: Who was the goddess of the Ephesians? The same, I say, who was the goddess of the Ephesians
#
# Question: Why wasn't David allowed to build God's house?
# Answer: Because he was a man of war
# Pre-trained Model Answer: Why wasn't David allowed to build God's house?
#
# The answer is that God's house was built by David.
#
# Fine-tuned Model Answer: Why wasn't David allowed to build God's house? Why did he have to take it down? and why is it taken down
# PEFT Model Answer: Why wasn't David allowed to build God's house? Because he was a man of war, and God was not with him.
#
# Question: On which island did Paul preach on his first missionary journey?
# Answer: Cyprus
# Pre-trained Model Answer: On which island did Paul preach on his first missionary journey?
#
# Paul's first missionary journey was to the island of Cyprus. He
# Fine-tuned Model Answer: On which island did Paul preach on his first missionary journey? And on which of the two did he take for his own home? And
# PEFT Model Answer: On which island did Paul preach on his first missionary journey? On the island of Cyprus. And on the island of Malta? On the
#
# Question: What was the name of Joseph's (son of Jacob) first born son?
# Answer: Manasseh
# Pre-trained Model Answer: What was the name of Joseph's (son of Jacob) first born son?
#
# The name of Joseph's first born son was Joseph.
#
#
# Fine-tuned Model Answer: What was the name of Joseph's (son of Jacob) first born son? And they said, The name of his first-born was Manasseh
# PEFT Model Answer: What was the name of Joseph's (son of Jacob) first born son? And Joseph said unto him, Jacob. And he said, I am thy
#
# Question: Which tribe went to war with the rest of the children of Israel?
# Answer: Benjamin
# Pre-trained Model Answer: Which tribe went to war with the rest of the children of Israel?
#
# The tribe of Levi.
#
# The tribe of Judah.
#
# Fine-tuned Model Answer: Which tribe went to war with the rest of the children of Israel? And they said, The tribe of Judah. And they said, What then
# PEFT Model Answer: Which tribe went to war with the rest of the children of Israel? The children of Ammon. And the children of Benjamin. And the children
#
# Question: Which king of Heshbon would not let the Israelites pass through his land?
# Answer: Sihon
# Pre-trained Model Answer: Which king of Heshbon would not let the Israelites pass through his land?
#
# The king of Heshbon would not let the Israelites pass
# Fine-tuned Model Answer: Which king of Heshbon would not let the Israelites pass through his land? and the king of Sihon would not let the Israelites pass through
# PEFT Model Answer: Which king of Heshbon would not let the Israelites pass through his land? And he said, I will not let the Israelites pass through my land
#
# Question: The angel said to Mary that Jesus would "reign over the house" of who?
# Answer: Jacob
# Pre-trained Model Answer: The angel said to Mary that Jesus would "reign over the house" of who? The Jews? The Christians? The Jews? The Christians? The Jews?
# Fine-tuned Model Answer: The angel said to Mary that Jesus would "reign over the house" of who? and to the angel that said this, Behold, the hand of the
# PEFT Model Answer: The angel said to Mary that Jesus would "reign over the house" of who? and she said, The house of Jacob. And the angel said, Be
#
# Pre-trained Model Accuracy: 0.023702031602708805
# Fine-tuned Model Accuracy: 0.01805869074492099
# PEFT Model Accuracy: 0.014672686230248307
